# %% [markdown]
# <a href="https://colab.research.google.com/github/PCeltide/Coursera/blob/main/Financial%20Analysis%20with%20ARIMA%20and%20Time%20Series/PACF_and_ACF.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from statsmodels.graphics.tsaplots import plot_pacf, plot_acf

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
x0 = np.random.randn(1000)

# %%
plt.plot(x0);

# %%
fig, ax = plt.subplots(figsize=(10, 5))
plot_pacf(x0, ax=ax);

# %%
x1 = [0]
for i in range(1000):
  x = 0.3 * x1[-1] + 0.1 * np.random.randn()
  x1.append(x)
x1 = np.array(x1)

# %%
plt.plot(x1);

# %%
fig, ax = plt.subplots(figsize=(10, 5))
plot_pacf(x1, ax=ax);

# %%
x1 = [0]
for i in range(1000):
  x = -0.5 * x1[-1] + 0.1 * np.random.randn()
  x1.append(x)
x1 = np.array(x1)

# %%
plt.plot(x1);

# %%
fig, ax = plt.subplots(figsize=(10, 5))
plot_pacf(x1, ax=ax);

# %%
x2 = [0, 0]
for i in range(1000):
  x = -0.5 * x2[-1] + 0.3 * x2[-2] + 0.1 * np.random.randn()
  x2.append(x)
x2 = np.array(x2)

# %%
plt.plot(x2);

# %%
fig, ax = plt.subplots(figsize=(10, 5))
plot_pacf(x2, ax=ax);

# %%
x5 = [0, 0, 0, 0, 0]
for i in range(1000):
  x = -0.5 * x5[-1] + 0.3 * x5[-2] + 0.2 * x5[-5] + 0.1 * np.random.randn()
  x5.append(x)
x5 = np.array(x5)

# %%
plt.plot(x5);

# %%
fig, ax = plt.subplots(figsize=(10, 5))
plot_pacf(x5, ax=ax);

# %%
# iid noise
fig, ax = plt.subplots(figsize=(10, 5))
plot_acf(np.random.randn(1000), ax=ax);

# %%
from logging import error
errors = 0.1 * np.random.randn(1000)
ma1 = []
for i in range(1000):
  if i >= 1:
    x =  0.5 * errors[i-1] + errors[i]
  else:
    x = 0
  ma1.append(x)
ma1 = np.array(ma1)

# %%
plt.plot(ma1);

# %%
fig, ax = plt.subplots(figsize=(10, 5))
plot_acf(ma1, ax=ax);

# %%
errors = 0.1 * np.random.randn(1000)
ma2 = []
for i in range(1000):
  x = 0.5 * errors[i-1] + 0.3 * errors[i-2] + errors[i]
  ma2.append(x)
ma2 = np.array(ma2)

# %%
plt.plot(ma2);

# %%
fig, ax = plt.subplots(figsize=(10, 5))
plot_acf(ma2, ax=ax);

# %%
errors = 0.1 * np.random.randn(1000)
ma3 = []
for i in range(1000):
  x =  0.5 * errors[i-1] - 0.3 * errors[i-2] + 0.25 * errors[i-3] + errors[i]
  ma3.append(x)
ma3 = np.array(ma3)

# %%
plt.plot(ma3);

# %%
fig, ax = plt.subplots(figsize=(10, 5))
plot_acf(ma3, ax=ax);

# %%
errors = 0.1 * np.random.randn(1000)
ma6 = []
for i in range(1000):
  x = 0.5 * errors[i-1] - 0.3 * errors[i-2] + 0.25 * errors[i-3] - 0.5 * errors[i-4] + 0.3 * errors[i-5] + 0.25 * errors[i-6] + errors[i]
  ma6.append(x)
ma6 = np.array(ma6)

# %%
plt.plot(ma6);

# %%
fig, ax = plt.subplots(figsize=(10, 5))
plot_acf(ma6, ax=ax);

# %% [markdown]
# ![](https://deeplearningcourses.com/notebooks_v3_pxl?sc=cWFkIiKGhgFV5RKGjNDXsg&n=PACF+and+ACF)
